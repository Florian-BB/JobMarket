# %% [markdown]
# ADZUNA utilise des catégories, je les récupère dans un premier temps

# %%
import requests
import json
import os

# mettre son appID et sa key puis supprimer.
appid = "a5b42571"
key = "60cc63829516c72184f41cb824543718"
url = "http://api.adzuna.com/v1/api/jobs/fr/categories?app_id={0}&app_key={1}&&content-type=application/json".format(appid, key)
req1 = requests.get(url).json()

categories = req1["results"]


tags = [] # j'initie cette liste qui récupèrera les tags qui correspondent aux catégories

for cat in categories:
    tags.append(cat["tag"]) # Pour chaque catégorie je récupère son tag

print(tags)
# Out:
# ['accounting-finance-jobs', 'it-jobs', 'sales-jobs', 'customer-services-jobs', 'engineering-jobs', 'hr-jobs', 'healthcare-nursing-jobs', 'hospitality-catering-jobs', 'pr-advertising-marketing-jobs', 'logistics-warehouse-jobs', 'teaching-jobs', 'trade-construction-jobs', 'admin-jobs', 'legal-jobs', 'creative-design-jobs', 'graduate-jobs', 'retail-jobs', 'consultancy-jobs', 'manufacturing-jobs', 'scientific-qa-jobs', 'social-work-jobs', 'travel-jobs', 'energy-oil-gas-jobs', 'property-jobs', 'charity-voluntary-jobs', 'domestic-help-cleaning-jobs', 'maintenance-jobs', 'part-time-jobs', 'other-general-jobs', 'unknown']

# %% [markdown]
# Recherches générales

# %%
results, success, failed = [], [], [] # Création de 3 listes, une pour les résultats, une pour la journalisation des succés et des échecs

for page in range(1, 3):
    url = "https://api.adzuna.com/v1/api/jobs/fr/search/{0}?app_id={1}&app_key={2}".format(page, appid, key)
    req = requests.get(url)
    if req.status_code == 200: # Si réponse positive, alors on récupère les données
        try:
            data = req.json()
            results.append(data["results"])
        except:
            failed.append("{} : {}".format(req.status_code, page))
            print(req.status_code, " pour la page ", page)
        else:
            print(req.status_code, " pour la page ", page)
            success.append("{} : {}".format(req.status_code, page))

    else :
        print(req.status_code, " pour la page ", page)
# Out:
# 200  pour la page  1
# 200  pour la page  2

# %% [markdown]
# Recherche par catégories

# %%
results, success, failed = [], [], [] # Création de 3 listes, une pour les résultats, une pour la journalisation des succés et des échecs
for tag in tags:
    for page in range(1, 2):
        url = "https://api.adzuna.com/v1/api/jobs/fr/search/{0}?app_id={1}&app_key={2}&category={3}".format(page, appid, key, tag)
        req = requests.get(url)
        if req.status_code == 200: # Si réponse positive, alors on récupère les données
            try:
                data = req.json()
                results.append(data["results"])
            except:
                failed.append("{} : {}".format(tag, page))
                print(req.status_code, " pour la page ", page, "de la catégorie ", tag)
            else:
                print(req.status_code, " pour la page ", page, "de la catégorie ", tag)
                success.append("{} : {}".format(tag, page))

        else :
            print(req.status_code, " pour la page ", page, "de la catégorie ", tag)
# Out:
# 200  pour la page  1 de la catégorie  it-jobs
# 200  pour la page  2 de la catégorie  it-jobs
# 200  pour la page  3 de la catégorie  it-jobs
# 200  pour la page  4 de la catégorie  it-jobs
# 200  pour la page  5 de la catégorie  it-jobs
# 200  pour la page  6 de la catégorie  it-jobs
# 200  pour la page  7 de la catégorie  it-jobs
# 200  pour la page  8 de la catégorie  it-jobs
# 200  pour la page  9 de la catégorie  it-jobs
# 200  pour la page  10 de la catégorie  it-jobs
# 200  pour la page  11 de la catégorie  it-jobs
# 200  pour la page  12 de la catégorie  it-jobs
# 200  pour la page  13 de la catégorie  it-jobs
# 200  pour la page  14 de la catégorie  it-jobs
# 200  pour la page  15 de la catégorie  it-jobs
# 200  pour la page  16 de la catégorie  it-jobs
# 200  pour la page  17 de la catégorie  it-jobs
# 200  pour la page  18 de la catégorie  it-jobs
# 200  pour la page  19 de la catégorie  it-jobs
# 200  pour la page  20 de la catégorie  it-jobs
# ...

# %% [markdown]
# Recherche par pays

# %%
countries = ["gb", "fr", "us","at","au","be","br","ca","ch"]
results, success, failed = [], [], [] # Création de 3 listes, une pour les résultats, une pour la journalisation des succés et des échecs
for country in countries:
    for page in range(1, 11):
        url = "https://api.adzuna.com/v1/api/jobs/{3}/search/{0}?app_id={1}&app_key={2}".format(page, appid, key, country)
        req = requests.get(url)
        if req.status_code == 200: # Si réponse positive, alors on récupère les données
            try:
                data = req.json()
                results.append(data["results"])
            except:
                failed.append("{} : {}".format(country, page))
                print(req.status_code, " pour la page ", page, "du pays ", country)
            else:
                print(req.status_code, " pour la page ", page, "du pays ", country)
                success.append("{} : {}".format(country, page))

        else :
            print(req.status_code, " pour la page ", page, "du pays ", country)
# Out:
# 200  pour la page  1 du pays  gb
# 200  pour la page  2 du pays  gb
# 200  pour la page  3 du pays  gb
# 200  pour la page  4 du pays  gb
# 200  pour la page  5 du pays  gb
# 200  pour la page  6 du pays  gb
# 200  pour la page  7 du pays  gb
# 200  pour la page  8 du pays  gb
# 200  pour la page  9 du pays  gb
# 200  pour la page  10 du pays  gb
# 200  pour la page  1 du pays  fr
# 200  pour la page  2 du pays  fr
# 200  pour la page  3 du pays  fr
# 200  pour la page  4 du pays  fr
# 200  pour la page  5 du pays  fr
# 200  pour la page  6 du pays  fr
# 200  pour la page  7 du pays  fr
# 200  pour la page  8 du pays  fr
# 200  pour la page  9 du pays  fr
# 200  pour la page  10 du pays  fr
# 200  pour la page  1 du pays  us
# 200  pour la page  2 du pays  us
# 200  pour la page  3 du pays  us
# 200  pour la page  4 du pays  us
# 200  pour la page  5 du pays  us
# 200  pour la page  6 du pays  us
# 200  pour la page  7 du pays  us
# 200  pour la page  8 du pays  us
# ...

# %% [markdown]
# Recherche des top companies

# %%
countries = ["gb", "fr", "us","at","au","be","br","ca","ch"]
top_companies = [] # Création de 3 listes, une pour les résultats, une pour la journalisation des succés et des échecs
for country in countries:
    url = "https://api.adzuna.com/v1/api/jobs/{2}/top_companies?app_id={0}&app_key={1}".format(appid, key, country)
    req = requests.get(url)
    if req.status_code == 200: # Si réponse positive, alors on récupère les données
        try:
            data = req.json()
            top_companies.append(data)
        except:
            print(req.status_code, " pour le pays ", country)
        else:
            print(req.status_code, " pour le pays ", country)

    else :
        print(req.status_code, " pour le pays ", country)
# Out:
# 200  pour le pays  gb
# 200  pour le pays  fr
# 200  pour le pays  us
# 200  pour le pays  at
# 200  pour le pays  au
# 200  pour le pays  be
# 200  pour le pays  br
# 200  pour le pays  ca
# 200  pour le pays  ch

# %%
for c in top_companies:
    print(len(c))
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %% [markdown]
# Affichage des données

# %%
print(len(results))

for page in results:
    print(page[0])
    for r in page:
        print("\nTitre du poste : ", r['title'])
        print("Nom de la société : ", r['company']['display_name'])
        print("Emplacement : ", r['location']['display_name'])
        print("Pays : ", r['location']['area'][0])
        print("Région : ", r['location']['area'][1])
        print("Département : ", r['location']['area'][2])
        print("Proche de  : ", r['location']['area'][3])
        print("Ville : ", r['location']['area'][4])
        print("Salaire : ", r['salary_is_predicted'])
        print("ID : ", r['id'])
        print("Type de contrat : ", r['contract_type'])
        print("Catégorie : ", r['category']['label'])
        print("Tag : ", r['category']['tag'])
        print("Date de création : ", r['created'])
# Out:
# 90
# ...

# %%
for page in results:
    for r in page:
        print("Nom de la société : ", r['company']['display_name'])
        print("ID : ", r['id'])
        print("Catégorie : ", r['category']['label'])
# Out:
# Nom de la société :  Akari
# ID :  4622634235
# Catégorie :  Healthcare & Nursing Jobs
# Nom de la société :  Akari
# ID :  4626062292
# Catégorie :  Healthcare & Nursing Jobs
# Nom de la société :  Just Childcare
# ID :  4610416609
# Catégorie :  Teaching Jobs
# Nom de la société :  Together Trust
# ID :  4641259815
# Catégorie :  Social work Jobs
# Nom de la société :  TSP
# ID :  4605396099
# Catégorie :  PR, Advertising & Marketing Jobs
# Nom de la société :  Event Security Southern LTD
# ID :  4614044274
# Catégorie :  Other/General Jobs
# Nom de la société :  Futuretech Info Vision Limited
# ID :  4608745985
# Catégorie :  IT Jobs
# Nom de la société :  JT Recruit
# ID :  4642236850
# Catégorie :  Other/General Jobs
# Nom de la société :  Just Childcare
# ID :  4624068903
# Catégorie :  Teaching Jobs
# Nom de la société :  Kids Planet
# ID :  4641633326
# Catégorie :  Teaching Jobs
# Nom de la société :  Just Childcare
# ID :  4620140728
# Catégorie :  Teaching Jobs
# ...

# %% [markdown]
# Enregistrement des données dans un fichier

# %%
"""with open("adzuna_results.json", "w") as outfile:
    json.dump(results, outfile)
"""
with open("adzuna_top_companies.json", "w") as outfile:
    json.dump(top_companies, outfile)

"""with open("adzuna_categories.json", "w") as outfile:
    json.dump(categories, outfile)"""
# Out:
# 'with open("adzuna_categories.json", "w") as outfile:\n    json.dump(categories, outfile)'
